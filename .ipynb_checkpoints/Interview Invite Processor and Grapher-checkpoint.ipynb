# %% [markdown]
# # **MD/PhD Application Cycle Analzyer**

# %%
import re
import pandas as pd
import numpy as np
import math
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# %%
def text_parser(filepath):
    """
    Function for parsing through a .txt file of schools with users + dates.
    Provide a filepath for each .txt file
    """
    school_list = []
    file = open(filepath)
    for line in file:
        school_list.append(line)
    return(school_list)

# %%
def datefinder(school_list):
    """
    Function for finding the school names, complete dates, and interview invite dates.
    Provide the parsed school list as a list object.
    Returns a dataframe of school names with complete dates and interview invite dates in separate columns
    as lists of dates for each school.
    """
    schools = []
    completes = []
    interviews = []
    for school in school_list:
        
        # For finding the complete program name at the start of each line, ending with ':'
        s = re.findall(pattern='^(.*?):', string=school)
        for program in s:
            schools.append(program)
        
        # For finding all instances of complete dates starting with 'C: ' and ending with ','
        c = re.findall(pattern='C: (.*?),', string=school)
        completes.append(c)
        
        # For finding all instances of interview invite dates starting with 'II: ' and ending with ')'
        i = re.findall(pattern='II: (.*?)\)', string=school)
        interviews.append(i)
        
    # Making a dateframe with schools, complete dates, and Interview Invite Dates as the columns
    ii = pd.DataFrame({'Schools': schools, 'Complete_Dates': completes, 'Interview_Invite_Dates': interviews})
    return(ii)

# %%
def datetimer(date_list, start_year):
    """
    A function for converting a list of strings into a list of datetime objects.
    Provide a list of dates in the form of a pandas dataframe column and the starting year of the cycle.
    Use function in a list comprehension to generate a new column of processed datetimes
    """
    dates = []
    for date in date_list:
        try:
            start = "/" + str(start_year)
            end = "/" + str(start_year + 1)
            newdate = date.split("/")
            if int(newdate[0]) < 4:
                d = date+end
                d2 = datetime.strptime(d, '%m/%d/%Y')   
                dates.append(d2)
            else:
                d3 = date+start
                d4 = datetime.strptime(d3, '%m/%d/%Y')
                dates.append(d4)
        except:
            pass
    return(dates)

# %%
school_list_2019 = text_parser(filepath = "C:/Users/TooFastDan/Documents/MD_PhD Application/Python Analysis/2018-2019 interview invites.txt")
school_list_2020 = text_parser(filepath = "C:/Users/TooFastDan/Documents/MD_PhD Application/Python Analysis/2019-2020 interview invites.txt")
school_list_2021 = text_parser(filepath = "C:/Users/TooFastDan/Documents/MD_PhD Application/Python Analysis/2020-2021 interview invites.txt")

# %% [markdown]
# ### **Calculating the total SDN users compared to the total applicant pool**

# %%
schools = []
other_users = []
first_users = []
for school in school_list_2019:
    # For finding the complete program name at the start of each line, ending with ':'
    s = re.findall(pattern='^(.*?):', string=school)
    for program in s:
        schools.append(program)
    users = re.findall(pattern='\)(.*?)\(', string=school)
    other_users.append(users)
    user1 = re.findall(pattern=':(.*?)\(', string=school)[0]
    first_users.append(user1)
sdners = pd.DataFrame({'Schools': schools, 'First User': first_users, 'Other Users': other_users})

# %%
# Out:
# [', PursuingHappy ',
#  ', loopthelooop ',
#  ', nakamarra ',
#  ', Purple Squid ',
#  ', coolalmostchilly ',
#  ', confudidoeskimo ',
#  ', JamDoc876 ',
#  ', tilapiaexpress ',
#  0      hopefulmedstudent2014
#  1            confudidoeskimo
#  2                    MehKMeh
#  3            binuclearcopper
#  4                looptheloop
#                 ...
#  74          Thoroughbred_Med
#  75                 ClimbsRox
#  76                   ugh1234
#  77                     Lucca
#  78                  mdphdpls
#  Name: First User, Length: 79, dtype: object,
#  0      hopefulmedstudent2014
#  1            confudidoeskimo
#  2                    MehKMeh
#  3            binuclearcopper
#  4                looptheloop
#                 ...
#  74          Thoroughbred_Med
#  75                 ClimbsRox
#  76                   ugh1234
#  77                     Lucca
#  78                  mdphdpls
#  Name: First User, Length: 79, dtype: object,
#  0      hopefulmedstudent2014
#  1            confudidoeskimo
#  2                    MehKMeh
#  3            binuclearcopper
#  4                looptheloop
#                 ...
#  74          Thoroughbred_Med
#  75                 ClimbsRox
#  76                   ugh1234
#  77                     Lucca
#  78                  mdphdpls
#  Name: First User, Length: 79, dtype: object,
#  0      hopefulmedstudent2014
#  1            confudidoeskimo
#  2                    MehKMeh
#  3            binuclearcopper
#  4                looptheloop
#                 ...
#  74          Thoroughbred_Med
#  75                 ClimbsRox
#  76                   ugh1234
#  77                     Lucca
#  78                  mdphdpls
#  Name: First User, Length: 79, dtype: object]

# %%
for users in other_users:
    complete_list = [users.append(user1) for user1 in first_user]
    print(complete_list)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# ### **Trying to Calculate the days between complete date and interview invite date**

# %%
def dater_timelapse(school_list, cycle):
    """
    write a description for this long-ass function
    """
    schools = []
    complete_ii = []
    for school in school_list:
        # For finding the complete program name at the start of each line, ending with ':'
        s = re.findall(pattern='^(.*?):', string=school)
        for program in s:
            schools.append(program)
        # For finding the complete and interview invite dates for each SDN user
        ci = re.findall(pattern='\((.*?)\)', string=school)
        complete_ii.append(ci)
    testdf = pd.DataFrame({'Schools': schools, 'Completes_Interviews': complete_ii})
    testdf['Cycle'] = cycle 
    testdf = testdf.explode('Completes_Interviews').reset_index(drop=True)
    
    completes = []
    interviews = []
    for ci in testdf['Completes_Interviews']:
        try:
            com = re.findall(pattern='C: (.+),', string=ci)[0]
            com = com + "/" + str(2020)
            com = datetime.strptime(com, '%m/%d/%Y')   
        except:
            com = np.nan
        completes.append(com)
    
        try:
            ii = re.findall(pattern='II:(.+)', string=ci)[0]
            ii = ii.replace(" ", "")
            ii_split = ii.split("/")
            if int(ii_split[0]) > 4:
                ii = ii + "/" + str(2020)
            else:
                ii = ii + "/" + str(2021)
            ii = datetime.strptime(ii, '%m/%d/%Y')   
        except:
            ii = np.nan
        interviews.append(ii)
    
    testdf['Complete_Date'] = completes
    testdf['Interview_Date'] = interviews
    testdf = testdf.dropna() # dropping any rows which contain an NA value
    testdf['timelapse'] = (testdf['Interview_Date'] - testdf['Complete_Date']).dt.days #timelapse
    
    return(testdf)

# %%
ii_2019 = dater_timelapse(school_list=school_list_2019, cycle='2018-2019')
ii_2020 = dater_timelapse(school_list=school_list_2020, cycle='2019-2020')
ii_2021 = dater_timelapse(school_list=school_list_2021, cycle='2020-2021')

results = pd.concat([ii_2019, ii_2020, ii_2021], axis=0).reset_index(drop=True)
results
# Out:
#                          Schools Completes_Interviews      Cycle  \
# 0                Albert Einstein    C: 8/13, II: 9/12  2018-2019
# 1                Albert Einstein    C: 8/20, II: 9/12  2018-2019
# 2                Albert Einstein     C: 8/3, II: 9/13  2018-2019
# 3                Albert Einstein    C: 8/22, II: 9/14  2018-2019
# 4                Albert Einstein     C: 7/4, II: 9/18  2018-2019
# ..                           ...                  ...        ...
# 983  Zucker at Hofstra/Northwell     C: 8/22, II: 9/4  2020-2021
# 984  Zucker at Hofstra/Northwell    C: 8/20, II: 9/16  2020-2021
# 985  Zucker at Hofstra/Northwell     C: 9/2, II: 9/18  2020-2021
# 986  Zucker at Hofstra/Northwell   C: 8/26, II: 10/29  2020-2021
# 987  Zucker at Hofstra/Northwell     C: 7/23, II: 9/8  2020-2021
#
#     Complete_Date Interview_Date  timelapse
# 0      2020-08-13     2020-09-12         30
# 1      2020-08-20     2020-09-12         23
# 2      2020-08-03     2020-09-13         41
# 3      2020-08-22     2020-09-14         23
# 4      2020-07-04     2020-09-18         76
# ..            ...            ...        ...
# 983    2020-08-22     2020-09-04         13
# 984    2020-08-20     2020-09-16         27
# 985    2020-09-02     2020-09-18         16
# 986    2020-08-26     2020-10-29         64
# 987    2020-07-23     2020-09-08         47
#
# [988 rows x 6 columns]

# %%
#results['Schools'].unique()

exclude = ['Creighton', 'Georgetown', 'Loyola University', 'LSUHSC', 'Medical College of Georgia',
          'Saint Louis University', 'Tulane', 'Uniformed Services', 'University of Kentucky',
          'University of Nebraska', 'University of Utah', 'Wayne State University',
           'West Virginia University', 'Kaiser', 'Louisiana State University', 
           'Rosalind Franklin University', 'Texas Tech', 'UC Davis', 'University of Missouri', 
           'University of South Florida', 'University of Toledo', 'Carle Illinois',
           'Cooper Medical School', 'Dartmouth', 'NIH Oxford/Cambridge', 'Sanford']

#filtering schools that are not in the negligible schools list
#ii_2020 = ii_2020[~ii_2020['Schools'].isin(exclude)]
results = results[~results['Schools'].isin(exclude)]
results.shape
# Out:
# (938, 6)

# %%
##### Calculating the Interquartile Range (IQR) #####
Q1 = results.groupby('Schools').quantile(0.25)
Q3 = results.groupby('Schools').quantile(0.75)
IQR = Q3['timelapse'] - Q1['timelapse']
IQR = pd.DataFrame(IQR).sort_values(by='timelapse')
display(IQR)
# Out:
#                                       timelapse
# Schools
# UT Medical Branch                          9.00
# University of Washington                  10.50
# UT San Antonio                            10.75
# Medical University of South Carolina      11.25
# Tri-I (Weill Cornell)                     11.50
# ...                                         ...
# WashU in St. Louis                        47.50
# Virginia Commonwealth                     48.50
# SUNY Downstate                            49.00
# UT Southwestern                           51.00
# University of Miami                       51.25
#
# [66 rows x 1 columns]

# %%
##### Sorting the results dataframe by mapping lowest to highest interquartile range #####
from pandas.api.types import CategoricalDtype
ordered = CategoricalDtype(IQR.index, ordered=True)
results['Schools'] = results['Schools'].astype(ordered)
results = results.sort_values(by='Schools')
results
# Out:
# <ipython-input-52-498bee098e00>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results['Schools'] = results['Schools'].astype(ordered)
#                  Schools Completes_Interviews      Cycle Complete_Date  \
# 253    UT Medical Branch     C: 9/6, II: 9/27  2018-2019    2020-09-06
# 251    UT Medical Branch     C: 9/8, II: 9/27  2018-2019    2020-09-08
# 252    UT Medical Branch     C: 8/1, II: 9/27  2018-2019    2020-08-01
# 581    UT Medical Branch    C: 9/18, II: 10/2  2019-2020    2020-09-18
# 582    UT Medical Branch    C: 9/15, II: 10/2  2019-2020    2020-09-15
# ..                   ...                  ...        ...           ...
# 223  University of Miami    C: 8/21, II: 9/24  2018-2019    2020-08-21
# 226  University of Miami    C: 10/23, II: 1/4  2018-2019    2020-10-23
# 880  University of Miami   C: 8/15, II: 12/22  2020-2021    2020-08-15
# 222  University of Miami     C: 8/7, II: 9/18  2018-2019    2020-08-07
# 227  University of Miami    C: 8/13, II: 1/23  2018-2019    2020-08-13
#
#     Interview_Date  timelapse
# 253     2020-09-27         21
# 251     2020-09-27         19
# 252     2020-09-27         57
# 581     2020-10-02         14
# 582     2020-10-02         17
# ..             ...        ...
# 223     2020-09-24         34
# 226     2021-01-04         73
# 880     2020-12-22        129
# 222     2020-09-18         42
# 227     2021-01-23        163
#
# [938 rows x 6 columns]

# %%
# %matplotlib inline
sns.set_style("whitegrid")
plt.figure(figsize=(12, 30))

plot = sns.boxplot(data=results, x='timelapse', y='Schools')
plot = sns.swarmplot(data=results, x='timelapse', y='Schools', color='black')

plt.xticks(rotation=90)
plot.set_ylabel("MD/PhD Programs", fontsize=16)
plot.set_xlabel("Wait Time Secondary Completion and Interview Invite (days)", fontsize=16)
plot.set_title("Days between Secondary and Interview Invite (SDN Past 3 Cycles)", fontsize=22)
plt.tight_layout()

plt.savefig('ii_2019-2020_timelapse_IQR_Sorted_vertical.jpg', dpi=150)
# Out:
# C:\Users\TooFastDan\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
schools = []
complete_ii = []
for school in school_list_2021:
    # For finding the complete program name at the start of each line, ending with ':'
    s = re.findall(pattern='^(.*?):', string=school)
    for program in s:
        schools.append(program)
    ci = re.findall(pattern='\((.*?)\)', string=school)
    complete_ii.append(ci)
testdf = pd.DataFrame({'Schools': schools, 'Completes_Interviews': complete_ii})
testdf = testdf.explode('Completes_Interviews').reset_index(drop=True)
testdf
# Out:
#                          Schools Completes_Interviews
# 0                Albert Einstein    C: 7/24, II: 9/18
# 1                Albert Einstein     C: 8/4, II: 9/18
# 2                Albert Einstein    C: 8/10, II: 9/18
# 3                Albert Einstein   C: 8/26, II: 10/21
# 4                Albert Einstein  C: 10/08, II: 11/04
# ..                           ...                  ...
# 360  Zucker at Hofstra/Northwell     C: 8/22, II: 9/4
# 361  Zucker at Hofstra/Northwell    C: 8/20, II: 9/16
# 362  Zucker at Hofstra/Northwell     C: 9/2, II: 9/18
# 363  Zucker at Hofstra/Northwell   C: 8/26, II: 10/29
# 364  Zucker at Hofstra/Northwell     C: 7/23, II: 9/8
#
# [365 rows x 2 columns]

# %%
completes = []
interviews = []
for ci in testdf['Completes_Interviews']:
    try:
        com = re.findall(pattern='C: (.+),', string=ci)[0]
        com = com + "/" + str(2020)
        com = datetime.strptime(com, '%m/%d/%Y')   
    except:
        com = np.nan
    completes.append(com)
    
    try:
        ii = re.findall(pattern='II:(.+)', string=ci)[0]
        ii = ii.replace(" ", "")
        ii_split = ii.split("/")
        if int(ii_split[0]) > 4:
            ii = ii + "/" + str(2020)
        else:
            ii = ii + "/" + str(2021)
        ii = datetime.strptime(ii, '%m/%d/%Y')   
    except:
        ii = np.nan
    interviews.append(ii)

# %%
testdf['Complete_Date'] = completes
testdf['Interview_Date'] = interviews
testdf = testdf.dropna() # dropping any rows which contain an NA value

# DO NOT RERUN - will throw an error
testdf['timelapse'] = (testdf['Interview_Date'] - testdf['Complete_Date']).dt.days
testdf.head()
# Out:
# <ipython-input-88-691935a59cd2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testdf['timelapse'] = (testdf['Interview_Date'] - testdf['Complete_Date']).dt.days
#            Schools Completes_Interviews Complete_Date Interview_Date  \
# 0  Albert Einstein    C: 7/24, II: 9/18    2020-07-24     2020-09-18
# 1  Albert Einstein     C: 8/4, II: 9/18    2020-08-04     2020-09-18
# 2  Albert Einstein    C: 8/10, II: 9/18    2020-08-10     2020-09-18
# 3  Albert Einstein   C: 8/26, II: 10/21    2020-08-26     2020-10-21
# 4  Albert Einstein  C: 10/08, II: 11/04    2020-10-08     2020-11-04
#
#    timelapse
# 0         56
# 1         45
# 2         39
# 3         56
# 4         27

# %% [markdown]
# ### **Finding Complete and Interview Dates for graphing later**

# %%
ii_2019 = datefinder(school_list=school_list_2019)
ii_2020 = datefinder(school_list=school_list_2020)
ii_2021 = datefinder(school_list=school_list_2021)
display(ii_2019.head(), ii_2020.head(), ii_2021.head())
print('Dimensions for:\n2019 cycle:', ii_2019.shape,
      '\n2020 cycle:', ii_2020.shape,
      '\n2021 cycle:', ii_2021.shape)
# Out:
#              Schools                                     Complete_Dates  \
# 0    Albert Einstein  [8/13, 8/20, 8/3, 8/22, 7/4, 7/5, 7/xx, 9/xx, ...
# 1             Baylor  [8/X, 7/4, 7/3, 7/8, 7/6, 9/6, 8/29, 8/5, 8/xx...
# 2  Boston University                   [07/09, 07/18, 7/31, 10/8, 8/13]
# 3       Case Western          [7/25, 7/31, 7/19, 7/14, 8/26, 12/1, 8/8]
# 4           Columbia                            [7/20, 8/2, 8/1, 10/09]
#
#                               Interview_Invite_Dates
# 0  [9/12, 9/12, 9/13, 9/14, 9/18, 9/12, 9/27, 10/...
# 1  [9/7, 9/7, 9/7, 9/7, 9/7, 10/2, 10/2, 11/15, 1...
# 2                 [09/06, 09/06, 10/11, 11/30, 9/11]
# 3          [8/17, 8/17, 8/17, 8/17, 2/10, 1/4, 8/16]
# 4                          [9/6, 10/9, 10/10, 12/03]
#              Schools                                     Complete_Dates  \
# 0    Albert Einstein        [7/27, 8/19, 7/24, 8/27, 8/19, 7/18, 10/24]
# 1             Baylor                  [7/9, 7/24, 7/1, 7/2, 7/09, 8/2x]
# 2  Boston University    [7/18, 7/18, 7/22, 7/18, 8/19, 7/9, 7/24, 7/27]
# 3       Case Western                [7/15, 7/x, 7/11, 7/23, 7/19, 7/1x]
# 4           Columbia  [7/20, 7/24, 8/13, 7/21, 7/11, 8/15, 7/x, 8/13...
#
#                               Interview_Invite_Dates
# 0          [9/5, 9/5, 9/6, 9/11, 9/17, 10/24, 12/13]
# 1              [8/28, 8/28, 8/28, 8/28, 8/28, 11/21]
# 2     [8/31, 9/3, 9/5, 8/29, 9/16, 9/25, 8/29, 10/3]
# 3               [8/14, 8/14, 8/14, 8/14, 8/14, 8/2x]
# 4  [8/30, 8/30, 9/5, 8/30, 9/5, 9/5, 9/9, 9/6, 9/...
#              Schools                                     Complete_Dates  \
# 0    Albert Einstein  [7/24, 8/4, 8/10, 8/26, 10/08, 8/21, 7/19, 10/...
# 1             Baylor                      [8:6, 7/16, 9/16, 8/20, 7/15]
# 2  Boston University                                [7/25, 8/18, 10/29]
# 3       Case Western  [7/16, 8/18, 7/25, 7/22, 8/22, 7/29, 8/23, 8/9...
# 4     Carle Illinois                                              [9/4]
#
#                               Interview_Invite_Dates
# 0  [9/18, 9/18, 9/18, 10/21, 11/04, 10/8, 10/9, 1...
# 1                    [9/23, 10/9, 11/4, 12/3, 12/22]
# 2                                [9/16, 9/23, 12/22]
# 3  [9/18, 9/18, 9/18, 9/18, 9/18, 9/18, 9/18, 9/1...
# 4                                            [11/12]
# Dimensions for:
# 2019 cycle: (79, 3)
# 2020 cycle: (78, 3)
# 2021 cycle: (77, 3)

# %%
ii_2019["Processed_Complete_Dates"] = [datetimer(date_list=dates, start_year=2021) for dates in ii_2019['Complete_Dates']]
ii_2019["Processed_Interview_Invites"] = [datetimer(date_list=dates, start_year=2021) for dates in ii_2019['Interview_Invite_Dates']]
ii_2019["cycle"] = "2018-2019"

ii_2020["Processed_Complete_Dates"] = [datetimer(date_list=dates, start_year=2021) for dates in ii_2020['Complete_Dates']]
ii_2020["Processed_Interview_Invites"] = [datetimer(date_list=dates, start_year=2021) for dates in ii_2020['Interview_Invite_Dates']]
ii_2020["cycle"] = "2019-2020"

ii_2021["Processed_Complete_Dates"] = [datetimer(date_list=dates, start_year=2021) for dates in ii_2021['Complete_Dates']]
ii_2021["Processed_Interview_Invites"] = [datetimer(date_list=dates, start_year=2021) for dates in ii_2021['Interview_Invite_Dates']]
ii_2021["cycle"] = "2020-2021"

# %%
ii_2019.head()
# Out:
#              Schools                                     Complete_Dates  \
# 0    Albert Einstein  [8/13, 8/20, 8/3, 8/22, 7/4, 7/5, 7/xx, 9/xx, ...
# 1             Baylor  [8/X, 7/4, 7/3, 7/8, 7/6, 9/6, 8/29, 8/5, 8/xx...
# 2  Boston University                   [07/09, 07/18, 7/31, 10/8, 8/13]
# 3       Case Western          [7/25, 7/31, 7/19, 7/14, 8/26, 12/1, 8/8]
# 4           Columbia                            [7/20, 8/2, 8/1, 10/09]
#
#                               Interview_Invite_Dates  \
# 0  [9/12, 9/12, 9/13, 9/14, 9/18, 9/12, 9/27, 10/...
# 1  [9/7, 9/7, 9/7, 9/7, 9/7, 10/2, 10/2, 11/15, 1...
# 2                 [09/06, 09/06, 10/11, 11/30, 9/11]
# 3          [8/17, 8/17, 8/17, 8/17, 2/10, 1/4, 8/16]
# 4                          [9/6, 10/9, 10/10, 12/03]
#
#                             Processed_Complete_Dates  \
# 0  [2021-08-13 00:00:00, 2021-08-20 00:00:00, 202...
# 1  [2021-07-04 00:00:00, 2021-07-03 00:00:00, 202...
# 2  [2021-07-09 00:00:00, 2021-07-18 00:00:00, 202...
# 3  [2021-07-25 00:00:00, 2021-07-31 00:00:00, 202...
# 4  [2021-07-20 00:00:00, 2021-08-02 00:00:00, 202...
#
#                          Processed_Interview_Invites      cycle
# 0  [2021-09-12 00:00:00, 2021-09-12 00:00:00, 202...  2018-2019
# 1  [2021-09-07 00:00:00, 2021-09-07 00:00:00, 202...  2018-2019
# 2  [2021-09-06 00:00:00, 2021-09-06 00:00:00, 202...  2018-2019
# 3  [2021-08-17 00:00:00, 2021-08-17 00:00:00, 202...  2018-2019
# 4  [2021-09-06 00:00:00, 2021-10-09 00:00:00, 202...  2018-2019

# %% [markdown]
# # **Graphing Interview Invites per School**

# %%
def school_ii_plotter(df, title):
    """For plotting interview invites for each school.
    Provide a dataframe (exploded) and title as a string."""
    # %matplotlib inline
    sns.set_style("ticks")
    plt.figure(figsize=(32, 12))
    plt.xticks(rotation=90)
    plot = sns.stripplot(data=df, y='Processed_Interview_Invites', x='Schools', hue='cycle')
    plot.set_xlabel("MD/PhD Programs", fontsize=16)
    plot.set_ylabel("Date of Interview Invitation", fontsize=16)
    plot.set_title(title, fontsize=24)
    plt.tight_layout()
    return(plot)

# %%
def ii_concat(df_list):
    dfs = []
    for df in df_list:
        df1 = df.iloc[: , [0, 4, 5]]
        df2 = df1.explode('Processed_Interview_Invites').reset_index(drop=True)
        dfs.append(df2)
    results = pd.concat(dfs, axis=0).reset_index(drop=True)
    return(results)

# %%
results = ii_concat(df_list=[ii_2019, ii_2020, ii_2021])
results
# Out:
#                           Schools Processed_Interview_Invites      cycle
# 0                 Albert Einstein                  2021-09-12  2018-2019
# 1                 Albert Einstein                  2021-09-12  2018-2019
# 2                 Albert Einstein                  2021-09-13  2018-2019
# 3                 Albert Einstein                  2021-09-14  2018-2019
# 4                 Albert Einstein                  2021-09-18  2018-2019
# ...                           ...                         ...        ...
# 1089  Zucker at Hofstra/Northwell                  2021-09-04  2020-2021
# 1090  Zucker at Hofstra/Northwell                  2021-09-16  2020-2021
# 1091  Zucker at Hofstra/Northwell                  2021-09-18  2020-2021
# 1092  Zucker at Hofstra/Northwell                  2021-10-29  2020-2021
# 1093  Zucker at Hofstra/Northwell                  2021-09-08  2020-2021
#
# [1094 rows x 3 columns]

# %%
school_iis = school_ii_plotter(df=results, title="Interview Invite Dates (SDN)")
school_iis.set_yticklabels(['August', 'September', 'October', 'November', 'December', 'January', 'February'])
#plt.savefigall_iis.png', dpi=300)
# Out:
# <ipython-input-36-c9ba9385ffa1>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   school_iis.set_yticklabels(['August', 'September', 'October', 'November', 'December', 'January', 'February'])
# [Text(0, 18840.0, 'August'),
#  Text(0, 18871.0, 'September'),
#  Text(0, 18901.0, 'October'),
#  Text(0, 18932.0, 'November'),
#  Text(0, 18962.0, 'December'),
#  Text(0, 18993.0, 'January'),
#  Text(0, 19024.0, 'February')]

# %% [markdown]
# # **Plotting a Population Density Curve**

# %%
results['Schools'].value_counts()
# Out:
# WashU in St. Louis                     31
# Perelman School of Medicine (UPenn)    29
# Stony Brook                            29
# UT San Antonio                         29
# Yale                                   27
#                                        ..
# LSUHSC                                  1
# Texas Tech                              1
# Carle Illinois                          1
# NIH Oxford/Cambridge                    1
# Uniformed Services                      1
# Name: Schools, Length: 93, dtype: int64

# %%
tick_labels = ['June', 'July', 'August', 'September', 'October', 'November', 'December',
              'January', 'February', 'March', 'April']

# %%
# %matplotlib inline
sns.set_style("ticks")
plt.figure(figsize=(9, 7))
plt.xticks(rotation=45)
plot = sns.kdeplot(data=results, x="Processed_Interview_Invites", hue='cycle', fill=True)
plot.set_xlabel("Interview Invite Dates", fontsize=12)
plot.set_xticklabels(tick_labels)
plot.set_ylabel("Density", fontsize=12)
plot.set_title("Density of Interview Invites for MD/PhD Programs (SDN)", fontsize=18)
plt.tight_layout()
plt.savefig('ii_kde.png', dpi=300)
# Out:
# <ipython-input-31-325441aac233>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plot.set_xticklabels(tick_labels)

# %%
filepath = "C:/Users/TooFastDan/Documents/MD_PhD Application/Python Analysis"
results.to_excel(filepath + "/II semi-cleaned.xlsx", index=False)

# %%
# ?sns.stripplot
