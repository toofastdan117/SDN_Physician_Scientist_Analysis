# %% [markdown]
# # **2021-2022 MD/PhD Cycle Analyzer**

# %%
import re
import pandas as pd
from pandas.api.types import CategoricalDtype
import numpy as np
import math
import string
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import plotly.express as px

# %%
def text_parser(filepath):
    """
    Function for parsing through a .txt file of schools with users + dates.
    Provide a filepath for each .txt file
    """
    school_list = []
    file = open(filepath)
    for line in file:
        school_list.append(line)
    return(school_list)

# %%
def cycle_generator(text_list, cycle_start_year):
    """
    Write a description for this function...
    """
    schools = []
    first_users = []
    other_users = []
    completes_interviews = []
    
    for school in text_list:
        s = re.findall(pattern="^(.*?):", string=school)
        for sc in s:
            schools.append(sc)
        
        user1 = re.findall(pattern=":(.*?)\(", string=school)[0]
        user1 = user1.replace(" ", "")
        first_users.append(user1)
        
        users = re.findall(pattern="\),(.*?)\(", string=school)
        users = [u.replace(" ", "") for u in users]
        other_users.append(users)
        
        ci = re.findall(pattern="\((.*?)\)", string=school)
        com_int = []
        for x in ci:
            x = x.replace(" ", "")
            x = x.upper()
            com_int.append(x)
        completes_interviews.append(com_int)
    
    all_users = []
    for f, o in zip(first_users, other_users):
        f = [f]
        total = f + o
        all_users.append(total)
    
    ii_df = pd.DataFrame({'schools': schools, 'users': all_users, 'complete_interview': completes_interviews})
    #return(ii_df)

    ii_df_users = ii_df.loc[:, ['schools', 'users']].explode('users').reset_index(drop=True)
    ii_df_ci = ii_df.loc[:, ['schools', 'complete_interview']].explode('complete_interview').reset_index(drop=True)
    #return(len(ii_df_users))
    #return(len(ii_df_ci))
    ii_df_users['complete_interview'] = ii_df_ci['complete_interview']
    ii_df_all = ii_df_users
    #return(ii_df_all)
    
    cs = []
    iis = []
    for ci in ii_df_all['complete_interview']:
        
        c = re.findall(pattern="C:(.*?),", string=ci)[0]
        c_dates = c.split('/')
        if int(c_dates[0]) > 5:
            try:
                c = c + "/" + str(cycle_start_year)
                c = datetime.strptime(c, '%m/%d/%Y')
            except:
                c = np.nan        
        if int(c_dates[0]) < 5:
            try:
                c = c + "/" + str(cycle_start_year + 1)
                c = datetime.strptime(c, '%m/%d/%Y')
            except:
                c = np.nan
        cs.append(c)
        
        ii = re.findall(pattern="II:(.*)", string=ci)[0]
        ii_dates = ii.split('/')
        if int(ii_dates[0]) > 5:
            try:
                ii = ii + "/" + str(cycle_start_year)
                ii = datetime.strptime(ii, '%m/%d/%Y')
            except:
                ii = np.nan        
        if int(ii_dates[0]) < 5:
            try:
                ii = ii + "/" + str(cycle_start_year + 1)
                ii = datetime.strptime(ii, '%m/%d/%Y')
            except:
                ii = np.nan
        iis.append(ii)
    
    ii_df_all['complete_date'] = cs
    ii_df_all['II_date'] = iis
    ii_df_all['wait_time'] = (ii_df_all['II_date'] - ii_df_all['complete_date']).dt.days
    ii_df_all['cycle'] = str(cycle_start_year) + "-" + str(cycle_start_year + 1)
    return(ii_df_all)

# %%
directory = "C:/Users/TooFastDan/Documents/MD_PhD Application/Python Analysis"
cycle_2021 = text_parser(filepath=directory + "/2021-2022 interview invites 2021-09-01.txt")
cycle_2020 = text_parser(filepath=directory + "/2020-2021 interview invites.txt")
cycle_2019 = text_parser(filepath=directory + "/2019-2020 interview invites.txt")
cycle_2018 = text_parser(filepath=directory + "/2018-2019 interview invites.txt")

# %%
ii_2021 = cycle_generator(text_list=cycle_2021, cycle_start_year=2021)
ii_2020 = cycle_generator(text_list=cycle_2020, cycle_start_year=2021)
ii_2019 = cycle_generator(text_list=cycle_2019, cycle_start_year=2021)
ii_2018 = cycle_generator(text_list=cycle_2018, cycle_start_year=2021)
print("2021-2022 cycle users:", len(ii_2021),
      "\n2020-2021 cycle users:", len(ii_2020), 
      "\n2019-2020 cycle users:", len(ii_2019),
      "\n2018-2019 cycle users:", len(ii_2018))
# Out:
# 2021-2022 cycle users: 151
# 2020-2021 cycle users: 362
# 2019-2020 cycle users: 359
# 2018-2019 cycle users: 397

# %%
# Redoing the cycle column
ii_2021['cycle'] = '2021-2022 *Incomplete'
ii_2020['cycle'] = '2020-2021'
ii_2019['cycle'] = '2019-2020'
ii_2018['cycle'] = '2018-2019'

# Dropping na values for interviews
ii_2021 = ii_2021[ii_2021['II_date'].notna()]
ii_2020 = ii_2020[ii_2020['II_date'].notna()]
ii_2019 = ii_2019[ii_2019['II_date'].notna()]
ii_2018 = ii_2018[ii_2018['II_date'].notna()]

# Sorting by interview invite date
ii_2021 = ii_2021.sort_values(by="II_date")
ii_2020 = ii_2020.sort_values(by="II_date")
ii_2019 = ii_2019.sort_values(by="II_date")
ii_2018 = ii_2018.sort_values(by="II_date")

# Numbering every II
ii_2021['rank'] = [i+1 for i in range(len(ii_2021))]
ii_2020['rank'] = [i+1 for i in range(len(ii_2020))]
ii_2019['rank'] = [i+1 for i in range(len(ii_2019))]
ii_2018['rank'] = [i+1 for i in range(len(ii_2018))]

# Creating a percent for suvival analysis
ii_2021['percent'] = (ii_2021['rank'] / 370) * 100  #assuming there are 370 final entries
ii_2020['percent'] = (ii_2020['rank'] / len(ii_2020)) * 100
ii_2019['percent'] = (ii_2019['rank'] / len(ii_2019)) * 100
ii_2018['percent'] = (ii_2018['rank'] / len(ii_2018)) * 100

# Concatenating all application cycles into one df
ii_all = pd.concat([ii_2020, ii_2019, ii_2018], axis=0, ignore_index=True)

# %%
#ii_all.to_excel(directory+"/all_iis_processed.xlsx", index=False)
display(ii_all)

print("2021-2022 cycle users:", len(ii_2021),
      "\n2020-2021 cycle users:", len(ii_2020), 
      "\n2019-2020 cycle users:", len(ii_2019),
      "\n2018-2019 cycle users:", len(ii_2018))
# Out:
#                      schools              users complete_interview  \
# 0           Thomas Jefferson             beener     C:7/13,II:7/30
# 1           Thomas Jefferson  plsletmebeadoctor     C:7/15,II:7/30
# 2           Thomas Jefferson        RiceCrisprs     C:7/13,II:7/30
# 3         Indiana University              jjame      C:7/13,II:8/4
# 4         Indiana University           scineurd      C:7/13,II:8/4
# ...                      ...                ...                ...
# 1093     University of Miami   Thoroughbred_med      C:8/5,II:1/21
# 1094               UC Irvine        cavesnakess      C:9/9,II:1/22
# 1095     University of Miami  peanutbuttercup24     C:8/13,II:1/23
# 1096            Case Western        cavesnakess     C:8/26,II:2/10
# 1097  University of Virginia        cavesnakess    C:12/15,II:2/11
#
#      complete_date    II_date  wait_time      cycle  rank     percent
# 0       2021-07-13 2021-07-30       17.0  2020-2021     1    0.276243
# 1       2021-07-15 2021-07-30       15.0  2020-2021     2    0.552486
# 2       2021-07-13 2021-07-30       17.0  2020-2021     3    0.828729
# 3       2021-07-13 2021-08-04       22.0  2020-2021     4    1.104972
# 4       2021-07-13 2021-08-04       22.0  2020-2021     5    1.381215
# ...            ...        ...        ...        ...   ...         ...
# 1093    2021-08-05 2022-01-21      169.0  2018-2019   390   98.984772
# 1094    2021-09-09 2022-01-22      135.0  2018-2019   391   99.238579
# 1095    2021-08-13 2022-01-23      163.0  2018-2019   392   99.492386
# 1096    2021-08-26 2022-02-10      168.0  2018-2019   393   99.746193
# 1097    2021-12-15 2022-02-11       58.0  2018-2019   394  100.000000
#
# [1098 rows x 9 columns]
# 2021-2022 cycle users: 145
# 2020-2021 cycle users: 362
# 2019-2020 cycle users: 342
# 2018-2019 cycle users: 394

# %% [markdown]
# ### Kaplan-Meier Suvival Curves

# %%
# %matplotlib inline
plt.style.use("seaborn-whitegrid")
fig, ax = plt.subplots(figsize=(10, 7))

ax.step(x=ii_2018['II_date'], y=ii_2018['percent'], label="2018-2019 (216/394 reporting)", where="post")
ax.step(x=ii_2019['II_date'], y=ii_2019['percent'], label="2019-2020 (223/342 reporting)", where="post")
ax.step(x=ii_2020['II_date'], y=ii_2020['percent'], label="2020-2021 (144/362 reporting)", where="post")
ax.step(x=ii_2021['II_date'], y=ii_2021['percent'], label="2021-2022 Incomplete (145/~370 reporting)", where="post")

plt.axvline(x=datetime.strptime("9/24/2021", '%m/%d/%Y'), color="#000000", ls="--", lw=1.5, 
            label='Current Date (9/24/2021)')

#plt.xlabel("Date")
tick_labels = ['August', 'September', 'October', 'November', 'December', 'January', 'February']
ax.set_xticklabels(tick_labels)
ax.set_ylabel("Percent Responses (%)", fontsize=15)
ax.set_title("Reverse kaplan-meier curves for interview invites (Source: SDN)", fontsize=20)
ax.legend(fontsize=14, loc='lower right', facecolor='white', framealpha=1, frameon=True)
plt.tight_layout()

#plt.savefig(directory+"/kaplan-meier iis.png", dpi=300)
# Out:
# <ipython-input-8-ad5403c05434>:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(tick_labels)

# %% [markdown]
# ### Population Density Curves

# %%
# %matplotlib inline
#sns.set_style("ticks")
plt.style.use("default")
plt.figure(figsize=(9, 7))

plot = sns.kdeplot(data=ii_all, x="II_date", hue='cycle', fill=True)

plt.xticks(rotation=45)
plot.set_xlabel("Interview Invite Dates", fontsize=12)
tick_labels = ["June", "July", "August", "September", "October", "November", "December", "January", "February", "March", "April"]
plot.set_xticklabels(tick_labels)
plot.set_ylabel("Density", fontsize=12)
plot.set_title("Density of Interview Invites for MD/PhD Programs (SDN)", fontsize=18)
plt.tight_layout()

plt.savefig('ii_kde.png', dpi=300)
# Out:
# <ipython-input-24-b9cfd61d2295>:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plot.set_xticklabels(tick_labels)

# %% [markdown]
# ### Making a plot of the most common days of the week to be sent interview invites

# %%
# 0 = monday, 1 = tueday, 2 = wednesday, 3 = thursday, 4 = friday, 5 = saturday, 6 = sunday
ii_2021["weekdays"] = [ii.weekday() for ii in ii_2021["II_date"]]
ii_2021["weekdays"].replace({0:"Monday", 1:"Tuesday", 2:"Wednesday", 3:"Thursday", 4:"Friday",
                            5:"Saturday", 6:"Sunday"}, inplace=True)
days_df = pd.DataFrame(ii_2021["weekdays"].value_counts().reset_index())
days_df.columns = ["Week Day", "Count"]

# Sorting according to weekday
days_df["Week Day"] = pd.Categorical(days_df["Week Day"], ["Monday", "Tuesday", "Wednesday", "Thursday",
                                                          "Friday", "Saturday", "Sunday"])
days_df.sort_values("Week Day", inplace=True)
days_df
# Out:
#     Week Day  Count
# 3     Monday     22
# 0    Tuesday     44
# 2  Wednesday     27
# 4   Thursday     18
# 1     Friday     34

# %%
# %matplotlib inline
plt.style.use("fivethirtyeight")
#sns.set_style("ticks")
plt.figure(figsize=(9, 7))

#colors = ['grey' for x in days_df["Week Day"]]
#bar = sns.barplot(data=days_df, x="Week Day", y="Count", palette=colors)
#colors = sns.color_palette("pastel")

pie = plt.pie(x=days_df["Count"], labels=days_df["Week Day"], autopct='%.0f%%')
plt.title("Days of the Week for Interview Invites (Source: 2021-2022 SDN)", fontsize=20)
plt.tight_layout()

plt.savefig('weekdays.png', dpi=300)

# %% [markdown]
# ## **Generating Summary Statistics**

# %%
def summary_stats(df):
    """
    Creating some summary statistics and making dataframes
    """
    total_iis = len(df)
    total_programs = len(pd.unique(df['schools']))
    sdn_users = len(pd.unique(df['users']))
    summary_stats = [total_iis, total_programs, sdn_users]
    rownames = ["Total number of interview invites reported on SDN", 
                "Number of programs reporting interviews on SDN",
                "Number of unique users on SDN"]
    summary_df = pd.DataFrame(summary_stats, index=rownames, columns=["Number Reporting"])
    school_iis = pd.DataFrame({"II's per school on SDN": df['schools'].value_counts()})
    user_iis = pd.DataFrame({"II's per SDN user": df['users'].value_counts()})
    return(summary_df, school_iis, user_iis)

# %%
summary_df, school_iis, user_iis = summary_stats(df=ii_2021)
display(summary_df)
display(school_iis)
display(user_iis)
# Out:
#                                                    Number Reporting
# Total number of interview invites reported on SDN               151
# Number of programs reporting interviews on SDN                   53
# Number of unique users on SDN                                    35
#                                                     II's per school on SDN
# Emory                                                                    9
# UT San Antonio                                                           7
# NYU                                                                      6
# University of Iowa                                                       6
# Northwestern                                                             6
# Weill Cornell/Rockefeller/Sloan Kettering - Tri-I                        5
# Case Western Reserve University                                          5
# Texas A&M                                                                5
# University of Pennsylvania                                               5
# Donald and Barbara Zucker School of Medicine at...                       5
# Columbia                                                                 5
# Vanderbilt                                                               4
# UT Southwestern                                                          4
# University of Massachusetts                                              4
# Icahn School of Medicine at Mount Sinai                                  4
# Ohio State University                                                    4
# Washington University in St. Louis                                       4
# Indiana University                                                       3
# Medical University of South Carolina                                     3
# University of Alabama at Birmingham                                      3
# Baylor                                                                   3
# University of Washington                                                 3
# University of Pittsburgh                                                 3
# OHSU                                                                     3
# University of Michigan                                                   2
# Pennsylvania State                                                       2
# University of Wisconsin-Madison                                          2
# University of Utah                                                       2
# Johns Hopkins                                                            2
# Stony Brook University                                                   2
# University of Chicago                                                    2
# Stanford                                                                 2
# University of Texas Houston McGovern                                     2
# University of California - Los Angeles                                   2
# University of Rochester                                                  2
# University of Cincinnati                                                 2
# University of Illinois at Chicago                                        2
# University of Connecticut                                                1
# Rutgers Robert Wood Johnson                                              1
# Einstein College of Medicine                                             1
# University of Minnesota                                                  1
# Harvard-MIT                                                              1
# Virginia Commonwealth University                                         1
# Wayne State                                                              1
# University of Kentucky                                                   1
# University of Virginia                                                   1
# Duke                                                                     1
# Sidney Kimmel Medical College - Jefferson                                1
# University of Florida                                                    1
# University of North Carolina                                             1
# University of Southern California-Caltech Keck                           1
# West Virginia University                                                 1
# University of South Florida Morsani                                      1
#                     II's per SDN user
# DrDriven07                         15
# mdphd63627                         10
# MacroPhagoCytosis                   9
# humoralhuman                        9
# larynxlady                          8
# mickmars51                          8
# yibs                                8
# toofastdan                          8
# pharmabro11                         6
# lucyaxolotl                         6
# dangoi1                             6
# NeuroImmunoMSTP                     5
# MDPhDcapable                        5
# dsracer9                            5
# sesteretina                         5
# baz2020                             4
# hanuman123                          4
# MarxistHegelian                     3
# Peritus_Medicus                     3
# misterjohndoe                       3
# chestnut                            3
# chips0807                           2
# installation2020                    2
# dyingpremed                         2
# TokyoDrifter                        2
# falarm                              1
# swagyolo                            1
# VaultArmitage                       1
# MT-GU-MD                            1
# aliceinscienceland                  1
# florizel                            1
# skeeter11                           1
# Toolcake                            1
# ThJSTRY                             1
# nyni                                1

# %%
### Writing to a multi-sheet excel doc ###
writer = pd.ExcelWriter(directory+'/2021-2022 summary stats.xlsx', engine='xlsxwriter')

summary_df.to_excel(writer, sheet_name="Summary_Stats")
school_iis.to_excel(writer, sheet_name="IIs_per_program")
user_iis.to_excel(writer, sheet_name="IIs_per_SDNuser")
ii_2021.to_excel(writer, sheet_name="cycle_processed", index=False)

writer.save()
writer.close()
# Out:
# C:\Users\TooFastDan\anaconda3\lib\site-packages\xlsxwriter\workbook.py:336: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %%
# Checking the number of schools, number of IIs per school, number of users, and number of IIs per user 
print("Total number of interview invites reported on SDN:", len(ii_2021))
print("\n")
print("Number of programs reporting interviews on SDN:", len(pd.unique(ii_2021['schools'])))
print("\n")
print("Number of individual users on SDN:", len(pd.unique(ii_2021['users'])))
print("\n")
print("Number of interview invites per program:\n", 
      pd.DataFrame({"ii_number": ii_2021['schools'].value_counts()}))
print("\n")
print("Number of interviews per user on SDN:\n",
      pd.DataFrame({"ii_per_user": ii_2021['users'].value_counts()}))
# Out:
# Total number of interview invites reported on SDN: 74
#
#
# Number of programs reporting interviews on SDN: 30
#
#
# Number of individual users on SDN: 28
#
#
# Number of interview invites per program:
#                                                      ii_number
# UT San Antonio                                              6
# Case Western Reserve University                             5
# Texas A&M                                                   5
# Donald and Barbara Zucker School of Medicine at...          4
# Northwestern                                                4
# Weill Cornell Tri-I                                         4
# Vanderbilt                                                  4
# Washington University in St. Louis                          3
# UT Southwestern                                             3
# Columbia                                                    3
# University of Pittsburgh                                    3
# Icahn School of Medicine at Mount Sinai                     3
# University of Washington                                    2
# University of Wisconsin-Madison                             2
# University of Iowa                                          2
# University of Alabama at Birmingham                         2
# NYU                                                         2
# University of Rochester                                     2
# Ohio State University                                       2
# Indiana University                                          2
# Stony Brook University                                      2
# Johns Hopkins                                               1
# University of Michigan                                      1
# University of South Florida Morsani                         1
# University of Connecticut                                   1
# University of Florida                                       1
# University of Minnesota                                     1
# West Virginia University                                    1
# Pennsylvania State                                          1
# University of Virginia                                      1
#
#
# Number of interviews per user on SDN:
#                      ii_per_user
# DrDriven07                    8
# lucyaxolotl                   6
# MacroPhagoCytosis             6
# mdphd63627                    6
# toofastdan                    5
# MDPhDcapable                  5
# humoralhuman                  4
# NeuroImmunoMSTP               3
# mickmars51                    3
# misterjohndoe                 3
# larynxlady                    3
# pharmabro11                   2
# baz2020                       2
# yibs                          2
# installation2020              2
# dsracer9                      2
# aliceinscienceland            1
# chips0807                     1
# swagyolo                      1
# florizel                      1
# Peritus_Medicus               1
# VaultArmitage                 1
# Toolcake                      1
# TokyoDrifter                  1
# ThJSTRY                       1
# sesteretina                   1
# MarxistHegelian               1
# nyni                          1

# %%
# ?plt.axvline

# %%
# ?plt.step

# %%
# ?plt.savefig

# %% [markdown]
# # Spare work for random analysis

# %%
schools = []
first_users = []
other_users = []
completes_interviews = []

for school in cycle_2022:
    s = re.findall(pattern="^(.*?):", string=school)
    for sc in s:
        schools.append(sc)
    
    user1 = re.findall(pattern=":(.*?)\(", string=school)[0]
    user1 = user1.replace(" ", "")
    first_users.append(user1)
    
    users = re.findall(pattern="\),(.*?)\(", string=school)
    users = [u.replace(" ", "") for u in users]
    other_users.append(users)
    
    ci = re.findall(pattern="\((.*?)\)", string=school)
    com_int = []
    for x in ci:
        x = x.replace(" ", "")
        x = x.upper()
        com_int.append(x)
    completes_interviews.append(com_int)

all_users = []
for f, o in zip(first_users, other_users):
    f = [f]
    total = f + o
    all_users.append(total)

ii_df = pd.DataFrame({'schools': schools, 'users': all_users, 'complete_interview': completes_interviews})
#display(ii_df)
# Out:
#                                               schools  \
# 0                     Case Western Reserve University
# 1                                            Columbia
# 2   Donald and Barbara Zucker School of Medicine a...
# 3             Icahn School of Medicine at Mount Sinai
# 4                                  Indiana University
# 5                                        Northwestern
# 6                                                 NYU
# 7                               Ohio State University
# 8                                           Texas A&M
# 9                                      UT San Antonio
# 10                                    UT Southwestern
# 11                University of Alabama at Birmingham
# 12                          University of Connecticut
# 13                              University of Florida
# 14                                 University of Iowa
# 15                             University of Michigan
# 16                            University of Minnesota
# 17                           University of Pittsburgh
# 18                            University of Rochester
# 19                University of South Florida Morsani
# 20                             University of Virginia
# 21                           University of Washington
# 22                    University of Wisconsin-Madison
# 23                             Stony Brook University
# 24                                         Vanderbilt
# 25                 Washington University in St. Louis
# 26          Weill Cornell/Rockefeller/Sloan Kettering
# 27                           West Virginia University
#
#                                                 users  \
# 0   [mdphd63627, toofastdan, ThJSTRY, DrDriven07, ...
# 1         [MacroPhagoCytosis, larynxlady, DrDriven07]
# 2   [florizel, installation2020, swagyolo, lucyaxo...
# 3       [MDPhDcapable, installation2020, lucyaxolotl]
# 4                         [misterjohndoe, DrDriven07]
# 5   [MacroPhagoCytosis, toofastdan, humoralhuman, ...
# 6                         [humoralhuman, lucyaxolotl]
# 7                            [mickmars51, DrDriven07]
# 8   [misterjohndoe, mickmars51, VaultArmitage, baz...
# 9   [MacroPhagoCytosis, larynxlady, DrDriven07, ba...
# 10        [toofastdan, NeuroImmunoMSTP, TokyoDrifter]
# 11                             [dsracer9, DrDriven07]
# 12                                             [yibs]
# 13                                       [mdphd63627]
# 14                   [misterjohndoe, MarxistHegelian]
# 15                                         [Toolcake]
# 16                                     [MDPhDcapable]
# 17    [aliceinscienceland, pharmabro11, MDPhDcapable]
# 18                    [MacroPhagoCytosis, DrDriven07]
# 19                                       [mdphd63627]
# 20                                       [mdphd63627]
# 21                         [toofastdan, humoralhuman]
# 22                             [dsracer9, larynxlady]
# 23                     [lucyaxolotl, Peritus_Medicus]
# 24                          [sesteretina, toofastdan]
# 25    [MacroPhagoCytosis, MDPhDcapable, humoralhuman]
# 26    [DrDriven07, mickmars51, NeuroImmunoMSTP, yibs]
# 27                                       [mdphd63627]
#
#                                    complete_interview
# 0   [C:7/16,II:8/26, C:7/16,II:8/26, C:7/20,II:8/2...
# 1     [C:7/14,II:8/25, C:7/15,II:8/25, C:7/8,II:8/25]
# 2   [C:7/9,II:8/11, C:8/8,II:8/11, C:7/18,II:8/18,...
# 3       [C:7/1X,II:8/0X, C:8/8,II:8/24, C:7/5,II:8/6]
# 4                      [C:7/1,II:8/10, C:7/2,II:8/10]
# 5   [C:7/28,II:8/25, C:7/19,II:8/25, C:7/24,II:8/2...
# 6                     [C:7/7,II:8/23, C:7/18,II:8/23]
# 7                    [C:7/18,II:8/13, C:7/18,II:8/13]
# 8   [C:7/19,II:7/30, C:8/6,II:8/16, C:8/12,II:8/16...
# 9   [C:7/10,II:7/30, C:7/10,II:7/30, C:7/10,II:7/3...
# 10   [C:6/26,II:8/26, C:7/30,II:8/26, C:7/29,II:8/27]
# 11                   [C:7/29,II:8/17, C:7/23,II:8/17]
# 12                                   [C:7/23,II:8/27]
# 13                                   [C:7/21,II:8/24]
# 14                   [C:7/24,II:8/27, C:7/15,II:8/27]
# 15                                   [C:6/25,II:8/10]
# 16                                   [C:8/0X,II:8/1X]
# 17   [C:7/16,II:8/20, C:7/15,II:8/27, C:7/1X,II:8/2X]
# 18                     [C:7/4,II:8/24, C:7/8,II:8/25]
# 19                                   [C:7/12,II:8/24]
# 20                                   [C:7/29,II:8/20]
# 21                     [C:7/19,II:8/2, C:7/23,II:8/2]
# 22                   [C:7/29,II:8/23, C:7/25,II:8/23]
# 23                   [C:7/15,II:8/25, C:7/28,II:8/25]
# 24                   [C:7/23,II:8/17, C:7/14,II:8/27]
# 25    [C:7/25,II:8/25, C:7/1X,II:8/2X, C:7/8,II:8/30]
# 26  [C:7/21,II:8/4, C:7/15,II:8/18, C:7/27,II:8/18...
# 27                                   [C:7/28,II:8/27]

# %%
ii_df_users = ii_df.loc[:, ['schools', 'users']].explode('users').reset_index(drop=True)
ii_df_ci = ii_df.loc[:, ['schools', 'complete_interview']].explode('complete_interview').reset_index(drop=True)
print(len(ii_df_users))
print(len(ii_df_ci))
ii_df_users['complete_interview'] = ii_df_ci['complete_interview']
ii_df_all = ii_df_users
display(ii_df_all)
# Out:
# 70
# 70
#                                       schools            users  \
# 0             Case Western Reserve University       mdphd63627
# 1             Case Western Reserve University       toofastdan
# 2             Case Western Reserve University          ThJSTRY
# 3             Case Western Reserve University       DrDriven07
# 4             Case Western Reserve University      pharmabro11
# ..                                        ...              ...
# 65  Weill Cornell/Rockefeller/Sloan Kettering       DrDriven07
# 66  Weill Cornell/Rockefeller/Sloan Kettering       mickmars51
# 67  Weill Cornell/Rockefeller/Sloan Kettering  NeuroImmunoMSTP
# 68  Weill Cornell/Rockefeller/Sloan Kettering             yibs
# 69                   West Virginia University       mdphd63627
#
#    complete_interview
# 0      C:7/16,II:8/26
# 1      C:7/16,II:8/26
# 2      C:7/20,II:8/26
# 3      C:7/15,II:8/26
# 4      C:7/23,II:8/26
# ..                ...
# 65      C:7/21,II:8/4
# 66     C:7/15,II:8/18
# 67     C:7/27,II:8/18
# 68     C:7/30,II:8/19
# 69     C:7/28,II:8/27
#
# [70 rows x 3 columns]

# %%
cs = []
iis = []
for ci in ii_df_all['complete_interview']:
    
    c = re.findall(pattern="C:(.*?),", string=ci)[0]
    c_dates = c.split('/')
    if int(c_dates[0]) > 5:
        try:
            c = c + "/2021"
            c = datetime.strptime(c, '%m/%d/%Y')
        except:
            c = np.nan        
    if int(c_dates[0]) < 5:
        try:
            c = c + "/2022"
            c = datetime.strptime(c, '%m/%d/%Y')
        except:
            c = np.nan
    cs.append(c)
    
    ii = re.findall(pattern="II:(.*)", string=ci)[0]
    ii_dates = ii.split('/')
    if int(ii_dates[0]) > 5:
        try:
            ii = ii + "/2021"
            ii = datetime.strptime(ii, '%m/%d/%Y')
        except:
            ii = np.nan        
    if int(ii_dates[0]) < 5:
        try:
            ii = ii + "/2022"
            ii = datetime.strptime(ii, '%m/%d/%Y')
        except:
            ii = np.nan
    iis.append(ii)

ii_df_all['complete_date'] = cs
ii_df_all['II_date'] = iis
ii_df_all
# Out:
#                                       schools            users  \
# 0             Case Western Reserve University       mdphd63627
# 1             Case Western Reserve University       toofastdan
# 2             Case Western Reserve University          ThJSTRY
# 3             Case Western Reserve University       DrDriven07
# 4             Case Western Reserve University      pharmabro11
# ..                                        ...              ...
# 65  Weill Cornell/Rockefeller/Sloan Kettering       DrDriven07
# 66  Weill Cornell/Rockefeller/Sloan Kettering       mickmars51
# 67  Weill Cornell/Rockefeller/Sloan Kettering  NeuroImmunoMSTP
# 68  Weill Cornell/Rockefeller/Sloan Kettering             yibs
# 69                   West Virginia University       mdphd63627
#
#    complete_interview complete_date    II_date
# 0      C:7/16,II:8/26    2021-07-16 2021-08-26
# 1      C:7/16,II:8/26    2021-07-16 2021-08-26
# 2      C:7/20,II:8/26    2021-07-20 2021-08-26
# 3      C:7/15,II:8/26    2021-07-15 2021-08-26
# 4      C:7/23,II:8/26    2021-07-23 2021-08-26
# ..                ...           ...        ...
# 65      C:7/21,II:8/4    2021-07-21 2021-08-04
# 66     C:7/15,II:8/18    2021-07-15 2021-08-18
# 67     C:7/27,II:8/18    2021-07-27 2021-08-18
# 68     C:7/30,II:8/19    2021-07-30 2021-08-19
# 69     C:7/28,II:8/27    2021-07-28 2021-08-27
#
# [70 rows x 5 columns]

# %%
# Checking the number of schools, number of IIs per school, number of users, and number of IIs per user 
print("Total number of interview invites reported on SDN:", len(ii_df_all))
print("\n")
print("Number of programs reporting interviews on SDN:", len(pd.unique(ii_df_all['schools'])))
print("\n")
print("Number of individual users on SDN:", len(pd.unique(ii_df_all['users'])))
print("\n")
print("Number of interview invites per program:\n", 
      pd.DataFrame({"ii_number": ii_df_all['schools'].value_counts()}))
print("\n")
print("Number of interviews per user on SDN:\n",
      pd.DataFrame({"ii_per_user": ii_df_all['users'].value_counts()}))
# Out:
# Total number of interview invites reported on SDN: 70
#
#
# Number of programs reporting interviews on SDN: 28
#
#
# Number of individual users on SDN: 26
#
#
# Number of interview invites per program:
#                                                      ii_number
# UT San Antonio                                              6
# Case Western Reserve University                             5
# Texas A&M                                                   5
# Northwestern                                                4
# Weill Cornell/Rockefeller/Sloan Kettering                   4
# Donald and Barbara Zucker School of Medicine at...          4
# Washington University in St. Louis                          3
# University of Pittsburgh                                    3
# Columbia                                                    3
# Icahn School of Medicine at Mount Sinai                     3
# UT Southwestern                                             3
# University of Iowa                                          2
# Stony Brook University                                      2
# Ohio State University                                       2
# NYU                                                         2
# University of Alabama at Birmingham                         2
# University of Washington                                    2
# University of Wisconsin-Madison                             2
# Vanderbilt                                                  2
# University of Rochester                                     2
# Indiana University                                          2
# University of Minnesota                                     1
# University of Michigan                                      1
# West Virginia University                                    1
# University of Florida                                       1
# University of Connecticut                                   1
# University of Virginia                                      1
# University of South Florida Morsani                         1
#
#
# Number of interviews per user on SDN:
#                      ii_per_user
# DrDriven07                    8
# lucyaxolotl                   6
# mdphd63627                    5
# MacroPhagoCytosis             5
# MDPhDcapable                  5
# toofastdan                    5
# humoralhuman                  4
# NeuroImmunoMSTP               3
# larynxlady                    3
# mickmars51                    3
# misterjohndoe                 3
# installation2020              2
# dsracer9                      2
# yibs                          2
# baz2020                       2
# pharmabro11                   2
# aliceinscienceland            1
# VaultArmitage                 1
# swagyolo                      1
# MarxistHegelian               1
# florizel                      1
# TokyoDrifter                  1
# sesteretina                   1
# Peritus_Medicus               1
# Toolcake                      1
# ThJSTRY                       1

# %%
ii_df_rank = ii_df_all.dropna().sort_values(by="II_date").reset_index(drop=True)
ii_df_rank['rank'] = [i+1 for i in range(len(ii_df_rank))]
ii_df_rank['percent'] = (ii_df_rank['rank'] / len(ii_df_rank)) * 100
ii_df_rank
# Out:
#                                schools            users complete_interview  \
# 0                       UT San Antonio  NeuroImmunoMSTP     C:7/10,II:7/30
# 1                       UT San Antonio      lucyaxolotl     C:7/10,II:7/30
# 2                       UT San Antonio          baz2020     C:7/10,II:7/30
# 3                       UT San Antonio       DrDriven07     C:7/10,II:7/30
# 4                            Texas A&M    misterjohndoe     C:7/19,II:7/30
# ..                                 ...              ...                ...
# 59                     UT Southwestern     TokyoDrifter     C:7/29,II:8/27
# 60                          Vanderbilt       toofastdan     C:7/14,II:8/27
# 61            University of Pittsburgh      pharmabro11     C:7/15,II:8/27
# 62            West Virginia University       mdphd63627     C:7/28,II:8/27
# 63  Washington University in St. Louis     humoralhuman      C:7/8,II:8/30
#
#    complete_date    II_date  rank   percent
# 0     2021-07-10 2021-07-30     1    1.5625
# 1     2021-07-10 2021-07-30     2    3.1250
# 2     2021-07-10 2021-07-30     3    4.6875
# 3     2021-07-10 2021-07-30     4    6.2500
# 4     2021-07-19 2021-07-30     5    7.8125
# ..           ...        ...   ...       ...
# 59    2021-07-29 2021-08-27    60   93.7500
# 60    2021-07-14 2021-08-27    61   95.3125
# 61    2021-07-15 2021-08-27    62   96.8750
# 62    2021-07-28 2021-08-27    63   98.4375
# 63    2021-07-08 2021-08-30    64  100.0000
#
# [64 rows x 7 columns]

# %%
# %matplotlib inline
plt.style.use("default")
plt.figure(figsize=(10, 8))

plt.step(x=ii_df_rank['II_date'], y=ii_df_rank['percent'], where="post")
plt.xlabel("Date")
plt.ylabel("Percentage of Responses(%)")
plt.tight_layout()

# %%
# ?plt.step

# %%
cyy = 2021
test_string = str(cyy) + "-" + str(cyy + 1)
print(test_string)
# Out:
# 2021-2022
