# %% [markdown]
# # US News Medical School Rank Analyzer

# %% [markdown]
# Begin by going to the US News ranks, clicking on research or primary care ranks, then clicking on the "Table View" tab.
#
# Scroll down to the bottom of the page to allow all schools to populate.
#
# Right click on the page and say "save as html".  Download the files and open up the html document in Notepad++.
#
# Copy and paste the long HTML line involving school ranks, paste it, and create a text file.  Import the text file here.

# %% [markdown]
# ### Importing the reuqired packages

# %%
import re
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Research Ranks

# %% [markdown]
# ### Reading the txt file and finding all the info for each school within the text

# %%
# Opening the txt file and selecting for all the school info
f = open("2021 US News Research Ranks.txt", "r")
f = f.read()
schools = re.findall(pattern='div name=(.*?)Span-sc-19wk4id-0 dJCHhF', string=f)

# %% [markdown]
# ### Finding the school name, state, city, rank, tuition, and enrollment for each school

# %%
# Finding school names for every school
names = []
for s in schools:
    s = re.findall(pattern='^"(.*?)" class', string=s)
    s = s[0]
    names.append(s)
    #print(s)

# %%
# Finding the cities and states in which schools are located
states = []
cities = []
for c in schools:
    c = re.findall(pattern='class="Paragraph-sc-1iyax29-0 lehlCB">(.*?)<\/p><p', string=c)
    c = c[0]
    c = c.split(',')
    if len(c) < 2:
        c.append("Unknown")
        c.reverse()
    ci = c[0]
    st = c[1].strip()
    states.append(st)
    cities.append(ci)
    #print(st, ci)

# %%
# Finding the school ranks from US News
ranks = []
for r in schools:
    r = re.findall(pattern='NameRank__RankPosition-sc-1yvv32p-0 bgsDIR gjlzZT">(.*?)<\/', string=r)
    if len(r) == 0:
        r = ["#Unranked "]
    r = r[0].replace(" ", "").replace("#", "")
    try:
        r = int(r)
    except:
        pass
    ranks.append(r)
    #print(r)

# %%
# Finding both in-state and out-of-state tuition for each school 
tuition1 = []
tuition2 = []
for t in schools:
    t = re.findall(pattern='TuitionItem-sc-19pb4sw-1 ihFPLW hxYZAl">(.*?) <span', string=t)
    if len(t) == 1:
        t.append(np.nan)
    if len(t) == 0:
        t = [np.nan, np.nan]
    tuition1.append(t[0])
    tuition2.append(t[1])
    #print(t)

# In-state tuition (or just regular tuition for private schools)
tuition_1 = []
for t in tuition1:
    try:
        t = t.strip('$').replace(',', '')
        t = float(t)
    except:
        pass
    tuition_1.append(t)
    #print(t)

# Optional out-out-state tuition for public schools
tuition_2 = []
for t in tuition2:
    try:
        t = t.strip('$').replace(',', '')
        t = float(t)
    except:
        pass
    tuition_2.append(t)
    #print(t)

# %%
# Finding the total school enrollment for each school
enrollment = []
for e in schools:
    e = re.findall(pattern='class="Span-sc-19wk4id-0 ihFPLW">(.*?)<\/span', string=e)
    e = e[0]
    e = e.replace(' ', '').replace(',', '')
    if e == "N/A":
        e = np.nan
    e = float(e)
    enrollment.append(e)
    #print(e)

# %% [markdown]
# ### Merging all data into a Dataframe and exporting

# %%
# Making a dataframe of all metrics
d = {"School Name": names, "State": states, "City": cities, "Rank": ranks, "In-State Tuition": tuition_1, "Out-of-State Tuition": tuition_2,
    "Enrollment": enrollment}
research_ranks = pd.DataFrame(d)
display(research_ranks)

# Optionally exporting to excel
#research_ranks.to_excel("2021 US News Research Ranks.xlsx", index=False)
# Out:
#                                        School Name State  \
# 0                               Harvard University    MA
# 1                   New York University (Grossman)    NY
# 2                                  Duke University    NC
# 3                              Columbia University    NY
# 4                              Stanford University    CA
# ..                                             ...   ...
# 185             University of Texas--Austin (Dell)    TX
# 186  University of Texas Medical Branch--Galveston    TX
# 187         University of Texas--Rio Grande Valley    TX
# 188               University of the Incarnate Word    TX
# 189            Washington State University (Floyd)    WA
#
#                                 City      Rank  In-State Tuition  \
# 0                             Boston         1           64984.0
# 1                           New York         2               0.0
# 2                             Durham         3           61170.0
# 3                           New York         4           64868.0
# 4                           Stanford         4           62193.0
# ..                               ...       ...               ...
# 185                           Austin  Unranked               NaN
# 186                        Galveston  Unranked               NaN
# 187                         Edinburg  Unranked               NaN
# 188  San Antonio &amp; Alamo Heights  Unranked               NaN
# 189                          Pullman  Unranked               NaN
#
#      Out-of-State Tuition  Enrollment
# 0                     NaN       700.0
# 1                     NaN       417.0
# 2                     NaN       502.0
# 3                     NaN       585.0
# 4                     NaN       484.0
# ..                    ...         ...
# 185                   NaN         NaN
# 186                   NaN         NaN
# 187                   NaN         NaN
# 188                   NaN         NaN
# 189                   NaN         NaN
#
# [190 rows x 7 columns]

# %% [markdown]
# # 1. Primary Care Ranks

# %% [markdown]
# ### Reading the txt file and finding all the info for each school within the text

# %%
# Opening the txt file and selecting for all the school info
f = open("2021 US News Primary Care Ranks.txt", "r")
f = f.read()
schools = re.findall(pattern='div name=(.*?)Span-sc-19wk4id-0 dJCHhF', string=f)

# %%
schools[16]
# Out:
# '"Baylor College of Medicine" class="Box-w0dun1-0 CYZBT"><h3 size="1" class="Heading__HeadingStyled-sc-1w5xk2o-0-h3 izrRLF Heading-sc-1w5xk2o-1 kQuiLM" spacing="0"><a href="https://www.usnews.com/best-graduate-schools/top-medical-schools/baylor-college-of-medicine-04110">Baylor College of Medicine</a></h3><p size="2" spacing="0" class="Paragraph-sc-1iyax29-0 lehlCB">Houston, TX</p><p size="2" spacing="0" class="Paragraph-sc-1iyax29-0 lehlCB"><a href="https://www.usnews.com/best-graduate-schools/top-medical-schools/primary-care-rankings" class="NameRank__Rank-sc-1yvv32p-1 hYlbKH"><strong size="2" class="Strong-sc-1m7huwa-0 NameRank__RankPosition-sc-1yvv32p-0 bgsDIR gjlzZT">#17 </strong>in <strong size="2" class="Strong-sc-1m7huwa-0 bgsDIR">Best Medical Schools: Primary Care</strong><span size="2" class="Span-sc-19wk4id-0 ljMlPu"> (tie)</span></a></p></div></span></td></tr><tr><td class="TableStacked__Cell-sc-82ags4-1 bDYRDH"><span size="3" class="Span-sc-19wk4id-0 cBeETl"><span size="3" class="Span-sc-19wk4id-0 BigSixResults__TuitionItem-sc-19pb4sw-1 ihFPLW hxYZAl">$19,425 <span size="2" color="#515767" class="Span-sc-19wk4id-0 ecUjjC">(full-time)</span><span size="1" color="#515767" class="Span-sc-19wk4id-0 BigSixResults__CellHeader-sc-19pb4sw-0 ekWA-dC eiQiAX Hide-kg09cx-0 gNDCfm">Tuition</span></span></span><span size="1" color="#515767" class="Span-sc-19wk4id-0 ekWA-dC" style="letter-spacing: 1px; display: none;"> TUITION</span></td></tr><tr><td class="TableStacked__Cell-sc-82ags4-1 bDYRDH"><span size="3" class="Span-sc-19wk4id-0 cBeETl"><span size="3" class="Span-sc-19wk4id-0 ihFPLW">753</span></span><span size="1" color="#515767" class="Span-sc-19wk4id-0 ekWA-dC" style="letter-spacing: 1px;"> ENROLLMENT (FULL-TIME)</span></td></tr><tr><td class="TableStacked__Cell-sc-82ags4-1 bDYRDH"><span size="3" class="Span-sc-19wk4id-0 cBeETl"><span size="3" class="Span-sc-19wk4id-0 ihFPLW"><a href="https://www.usnews.com/usnews/store/medical_school_compass.htm" data-tracking-id="compass_tracking_click" data-tracking-campaign="compass_unlock" data-tracking-placement="grad_compass_searchranking_table_scores" letter-spacing="0.6" prefix="\\00ab\\00a0" class="Anchor-byh49a-0 BigSixResults__CompassLink-sc-19pb4sw-3 kQpddJ jhiBIB"><svg role="img" width="1.5rem" height="1.5rem" class="Icon-sc-9wq8ul-0 BigSixResults__Iconography-sc-19pb4sw-2 jXPyCS dtEgMq"><use xlink:href="#lock" filter="0"></use></svg><span size="1" class="Span-sc-19wk4id-0 eSJUVD Hide-kg09cx-0 gNDCfm">Unlock MCAT TOTAL SCORE</span></a></span></span><span size="1" color="#515767" class="Span-sc-19wk4id-0 ekWA-dC" style="letter-spacing: 1px; display: none;"> MCAT TOTAL SCORE</span></td></tr><tr><td class="TableStacked__Cell-sc-82ags4-1 bDYRDH"><span size="3" class="Span-sc-19wk4id-0 cBeETl"><div class="Box-w0dun1-0 CYZBT BigSixResults__CompareCheckbox-sc-19pb4sw-6 dtPrLc"><span class="input__Container-sc-1ie8rf0-0 bkIyZs"><label class="input__Label-sc-1ie8rf0-5 jWYghE size-small"><input type="checkbox" name="compare-04110" class="input__InputHidden-sc-1ie8rf0-6 iVnrPV" value="04110"><span class="input__Control-sc-1ie8rf0-1 gqWZCV"><svg viewBox="0 0 100 100"><path fill="none" stroke-width="13" stroke-linecap="round" stroke-linejoin="round" stroke-miterlimit="10" d="M12.1 52.1l24.4 24.4 53-53"></path></svg></span><span class="input__LabelSpan-sc-1ie8rf0-2 ePSvCb"><span><span class="Span-sc-19wk4id-0 lmVojs sm-hide" size="3"></span><span class="Span-sc-19wk4id-0 lmVojs md-hide lg-hide" size="3">Compare</span></span></span></label></span></div></span><span size="1" color="#515767" class="Span-sc-19wk4id-0 ekWA-dC" style="letter-spacing: 1px; display: none;"> Compare</span></td></tr></tbody></table></td></tr><tr class="" style="display: table-row;"><td><table><tbody><tr><td style="vertical-align: top;"><span size="4" class="'

# %% [markdown]
# ### Finding the school name, state, city, rank, tuition, and enrollment for each school

# %%
# Finding school names for every school
names = []
for s in schools:
    s = re.findall(pattern='^"(.*?)" class', string=s)
    s = s[0]
    names.append(s)
    #print(s)

# %%
# Finding the cities and states in which schools are located
states = []
cities = []
for c in schools:
    c = re.findall(pattern='class="Paragraph-sc-1iyax29-0 lehlCB">(.*?)<\/p><p', string=c)
    c = c[0]
    c = c.split(',')
    if len(c) < 2:
        c.append("Unknown")
        c.reverse()
    ci = c[0]
    st = c[1].strip()
    states.append(st)
    cities.append(ci)
    #print(st, ci)

# %%
# Finding the school ranks from US News
ranks = []
for r in schools:
    r = re.findall(pattern='NameRank__RankPosition-sc-1yvv32p-0 bgsDIR gjlzZT">(.*?)<\/', string=r)
    if len(r) == 0:
        r = ["#Unranked "]
    r = r[0].replace(" ", "").replace("#", "")
    try:
        r = int(r)
    except:
        pass
    ranks.append(r)
    #print(r)

# %%
# Finding both in-state and out-of-state tuition for each school 
tuition1 = []
tuition2 = []
for t in schools:
    t = re.findall(pattern='TuitionItem-sc-19pb4sw-1 ihFPLW hxYZAl">(.*?) <span', string=t)
    if len(t) == 1:
        t.append(np.nan)
    if len(t) == 0:
        t = [np.nan, np.nan]
    tuition1.append(t[0])
    tuition2.append(t[1])
    #print(t)

# In-state tuition (or just regular tuition for private schools)
tuition_1 = []
for t in tuition1:
    try:
        t = t.strip('$').replace(',', '')
        t = float(t)
    except:
        pass
    tuition_1.append(t)
    #print(t)

# Optional out-out-state tuition for public schools
tuition_2 = []
for t in tuition2:
    try:
        t = t.strip('$').replace(',', '')
        t = float(t)
    except:
        pass
    tuition_2.append(t)
    #print(t)

# %%
# Finding the total school enrollment for each school
enrollment = []
for e in schools:
    e = re.findall(pattern='class="Span-sc-19wk4id-0 ihFPLW">(.*?)<\/span', string=e)
    e = e[0]
    e = e.replace(' ', '').replace(',', '')
    if e == "N/A":
        e = np.nan
    e = float(e)
    enrollment.append(e)
    #print(e)

# %% [markdown]
# ### Merging all data into a Dataframe and exporting

# %%
# Making a dataframe of all metrics
d = {"School Name": names, "State": states, "City": cities, "Rank": ranks, "In-State Tuition": tuition_1, "Out-of-State Tuition": tuition_2,
    "Enrollment": enrollment}
primary_care_ranks = pd.DataFrame(d)
display(primary_care_ranks)

# Optionally exporting to excel
#primary_care_ranks.to_excel("2021 US News Primary Care Ranks.xlsx", index=False)
# Out:
#                                        School Name State  \
# 0                         University of Washington    WA
# 1          University of California--San Francisco    CA
# 2        University of North Carolina--Chapel Hill    NC
# 3             Oregon Health and Science University    OR
# 4                          University of Minnesota    MN
# ..                                             ...   ...
# 185             University of Texas--Austin (Dell)    TX
# 186  University of Texas Medical Branch--Galveston    TX
# 187         University of Texas--Rio Grande Valley    TX
# 188               University of the Incarnate Word    TX
# 189            Washington State University (Floyd)    WA
#
#                                 City      Rank  In-State Tuition  \
# 0                            Seattle         1           37760.0
# 1                      San Francisco         2           36342.0
# 2                        Chapel Hill         3           32746.0
# 3                           Portland         4           44356.0
# 4                        Minneapolis         5           40191.0
# ..                               ...       ...               ...
# 185                           Austin  Unranked               NaN
# 186                        Galveston  Unranked               NaN
# 187                         Edinburg  Unranked               NaN
# 188  San Antonio &amp; Alamo Heights  Unranked               NaN
# 189                          Pullman  Unranked               NaN
#
#      Out-of-State Tuition  Enrollment
# 0                 69186.0      1123.0
# 1                 48587.0       664.0
# 2                 60140.0       782.0
# 3                 68184.0       617.0
# 4                 57678.0      1051.0
# ..                    ...         ...
# 185                   NaN         NaN
# 186                   NaN         NaN
# 187                   NaN         NaN
# 188                   NaN         NaN
# 189                   NaN         NaN
#
# [190 rows x 7 columns]

# %% [markdown]
# ### Messing around and getting a list of MSTP schools

# %%
mstp = pd.read_excel("MSTP Schools.xlsx", sheet_name="2021 MSTP")
mstp = mstp[mstp["MSTP"] == "Yes"]
mstp_schools = np.array(mstp["School Name"])
display(mstp.head())
mstp.shape
# Out:
#                                  School Name State           City MSTP
# 0                   University of Washington    WA        Seattle  Yes
# 1    University of California--San Francisco    CA  San Francisco  Yes
# 2  University of North Carolina--Chapel Hill    NC    Chapel Hill  Yes
# 3       Oregon Health and Science University    OR       Portland  Yes
# 4                    University of Minnesota    MN    Minneapolis  Yes
# (51, 4)

# %%
mstp_schools
# Out:
# array(['University of Washington',
#        'University of California--San Francisco',
#        'University of North Carolina--Chapel Hill',
#        'Oregon Health and Science University', 'University of Minnesota',
#        'University of Colorado', 'Harvard University',
#        'University of Kansas Medical Center',
#        'University of Massachusetts--Worcester',
#        'University of California--Los Angeles (Geffen)',
#        'University of Wisconsin--Madison', 'University of Rochester',
#        'University of Michigan--Ann Arbor', 'University of Maryland',
#        'Baylor College of Medicine', 'University of Virginia',
#        'University of Alabama--Birmingham', 'Stanford University',
#        'University of Iowa (Carver)',
#        'University of Pennsylvania (Perelman)', 'Ohio State University',
#        'University of California--San Diego',
#        'University of Texas Southwestern Medical Center',
#        'University of Chicago (Pritzker)', 'University of Pittsburgh',
#        'Emory University', 'Indiana University--Indianapolis',
#        'Vanderbilt University', 'Northwestern University (Feinberg)',
#        'Mayo Clinic School of Medicine (Alix)',
#        'New York University (Grossman)',
#        'University of California--Irvine',
#        'University of Texas Health Science Center--San Antonio',
#        'Cornell University (Weill)', 'Duke University',
#        'Tufts University', 'University of Arizona--Tucson',
#        'Johns Hopkins University', 'University of Cincinnati',
#        'Washington University in St. Louis', 'Yale University',
#        'Columbia University', 'University of Illinois',
#        'Albert Einstein College of Medicine',
#        'Case Western Reserve University',
#        'University of Texas Health Science Center--Houston (McGovern)',
#        'Stony Brook University--SUNY', 'University of Miami (Miller)',
#        'Medical College of Wisconsin',
#        'Medical University of South Carolina',
#        'Pennsylvania State University College of Medicine'], dtype=object)
